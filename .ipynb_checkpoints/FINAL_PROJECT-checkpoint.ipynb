# %% [markdown]
# ## 2. METRIC

# %%
import pandas as pd

parking= pd.read_csv("final.csv")
parking.head(15)
# Out:
#                    id                         location location_type  \
# 0   410168-SCHEDR4402                      SCHENLEY DR     On street
# 1   421009-CEDAR-0302                        CEDAR AVE     On street
# 2          PBP 412083                FORBES MURRAY LOT           NaN
# 3   409242-NDTHRG0106                   N DITHRIDGE ST     On street
# 4              PBP412  Virtual Terminal for ParkMobile  Virtual Zone
# 5   426002-CENTRE1802                       CENTRE AVE     On street
# 6   407118-MEYRAN0203                       MEYRAN AVE     On street
# 7   402403-BLVDAL0004                   BLVD OF ALLIES     On street
# 8   415018-ECARSN0701                      E CARSON ST     On street
# 9   421054-WESTRN0802                      WESTERN AVE     On street
# 10  415039-ECARSN2004                      E CARSON ST     On street
# 11  404470-PENAVE2001                         PENN AVE     On street
# 12  401350-SMTHFD0601                       SMITHFIELD     On street
# ...
