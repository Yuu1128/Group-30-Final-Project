# %% [markdown]
# # 1. Introduction

# %% [markdown]
# For CMPINF0010's final project, our group(group 30) will work collaboraively to analyze dataset of Pittsburgh's neighborhood based on different attributes. Specifically, I chose safety as my attribute. I think safety would be most people's first priority because getting harmed and be near a dangerous area would not be a pleasant situation. If someone gets harmed, it will be detrimental to their business, since they will have to spend money at hospitals, clinics, etc.

# %% [markdown]
# In addition, people feel safe when they are respected, valued, and have access to a full range of health, social, natural, and educational resources. Feeling safe will also link to a lower rates of mental illness, greater social interaction, and neighbourhood trust.

# %% [markdown]
# # 2. The Sub-Metric

# %%
import pandas as pd

arrest = pd.read_csv("arrest.csv")
arrest.head(10)
# Out:
#         PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 0  1975272  16158872  42.0      F    B  2016-08-24T12:20:00
# 1  1974456  16144120  31.0      M    W  2016-08-03T14:55:00
# 2  1974466  16144165  63.0      F    B  2016-08-03T16:45:00
# 3  1974550  16145257  25.0      F    W  2016-08-05T02:36:00
# 4  1974596  16145962  25.0      M    B  2016-08-06T02:00:00
# 5  1974556  16144301  45.0      M    W  2016-08-15T13:30:00
# 6  1974628  16147655  29.0      M    W  2016-08-16T13:00:00
# 7  1974607  16146037  21.0      F    B  2016-08-16T04:25:00
# 8  1974643  16132537  17.0      M    B  2016-08-29T17:55:00
# 9  1974647  16138646  14.0      M    B  2016-08-23T13:36:00
#
#                                      ARRESTLOCATION  \
# 0         4700 Block Centre AV Pittsburgh, PA 15213
# 1  4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2        900 Block Freeport RD Fox Chapel, PA 15238
# 3       Foreland ST & Cedar AV Pittsburgh, PA 15212
# ...

# %%
import pandas as pd

arrest = pd.read_csv("arrest.csv")
arrest['INCIDENTNEIGHBORHOOD'].value_counts()
# Out:
# Central Business District    3785
# South Side Flats             3186
# Carrick                      2199
# East Allegheny               2014
# Homewood South               1941
#                              ...
# Ridgemont                      35
# Central Northside              23
# Mt. Oliver Boro                18
# Troy Hill-Herrs Island          6
# Mt. Oliver Neighborhood         2
# Name: INCIDENTNEIGHBORHOOD, Length: 98, dtype: int64

# %% [markdown]
# # 3. The Best Neighborhood

# %%
import pandas as pd

arrest = pd.read_csv("arrest.csv")
arrest["INCIDENTNEIGHBORHOOD"].value_counts().plot(kind ='bar',rot = 90, figsize = (20,25))

# %%
import pandas as pd
import matplotlib.pyplot as plt

arrest = pd.read_csv("arrest.csv")
top_20 = (arrest['INCIDENTNEIGHBORHOOD'].value_counts()).iloc[:20]

#create bar chart to visualize top 20 values
top_20.plot(kind ='bar')

# %% [markdown]
# # 4. Conclusion
